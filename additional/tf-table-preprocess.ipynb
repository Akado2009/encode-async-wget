# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("tf-chip-seq.tsv", sep="\t")

# %%
df.columns
# Out:
# Index(['ID', 'Accession', 'Assay name', 'Assay title', 'Target of assay',
#        'Target gene symbol', 'Biosample summary', 'Biosample term name',
#        'Description', 'Lab', 'Project', 'Status', 'Files', 'Related series',
#        'Biosample accession', 'Biological replicate', 'Technical replicate',
#        'Linked antibody', 'Organism', 'Life stage', 'Age', 'Age units',
#        'Biosample treatment', 'Biosample treatment ontology ID',
#        'Biosample treatment concentration',
#        'Biosample treatment concentration units',
#        'Biosample treatment duration', 'Biosample treatment duration units',
#        'Synchronization', 'Post-synchronization time',
#        'Post-synchronization time units', 'Replicates'],
#       dtype='object')

# %%
df.head()
# Out:
#                           ID    Accession Assay name  Assay title  \
# 0  /experiments/ENCSR569XNP/  ENCSR569XNP   ChIP-seq  TF ChIP-seq
# 1  /experiments/ENCSR000BLM/  ENCSR000BLM   ChIP-seq  TF ChIP-seq
# 2  /experiments/ENCSR000BLT/  ENCSR000BLT   ChIP-seq  TF ChIP-seq
# 3  /experiments/ENCSR703KWN/  ENCSR703KWN   ChIP-seq  TF ChIP-seq
# 4  /experiments/ENCSR894QWM/  ENCSR894QWM   ChIP-seq  TF ChIP-seq
#
#    Target of assay Target gene symbol  \
# 0              FOS                FOS
# 1            EP300              EP300
# 2              YY1                YY1
# 3             EZH2               EZH2
# 4  EZH2phosphoT487               EZH2
#
#                                    Biosample summary Biosample term name  \
# 0                                              MCF-7               MCF-7
# 1  T47D treated with 0.02% dimethyl sulfoxide for...                T47D
# 2                                            GM12892             GM12892
# ...

# %%
lines = np.unique(df["Biosample term name"].values.tolist())

# %%
len(lines)
# Out:
# 161

# %%
proteins = np.unique(df["Target gene symbol"].values.tolist())

# %%
proteins
# Out:
# array(['ADNP', 'AEBP2', 'AFF1', 'AGO1', 'AGO2', 'AHR', 'ARHGAP35',
#        'ARID1B', 'ARID2', 'ARID3A', 'ARID4B', 'ARNT', 'ASH1L', 'ASH2L',
#        'ATF1', 'ATF2', 'ATF3', 'ATF4', 'ATF7', 'ATM', 'BACH1', 'BATF',
#        'BCL11A', 'BCL11B', 'BCL3', 'BCL6', 'BCL6B', 'BCLAF1', 'BCOR',
#        'BDP1', 'BHLHE40', 'BORCS8-MEF2B,MEF2B', 'BRCA1', 'BRD4', 'BRD9',
#        'BRF1', 'BRF2', 'CAVIN1', 'CBFA2T2', 'CBFA2T3', 'CBFB', 'CBLL2',
#        'CBX1', 'CBX2', 'CBX3', 'CBX5', 'CBX8', 'CC2D1A', 'CCAR2', 'CCNT2',
#        'CDC5L', 'CEBPA', 'CEBPB', 'CEBPG', 'CEBPZ', 'CHAMP1', 'CHD1',
#        'CHD2', 'CHD4', 'CHD7', 'CLOCK', 'COMMD3-BMI1,BMI1', 'COPS2',
#        'CREB1', 'CREB3', 'CREB3L1', 'CREBBP', 'CREM', 'CSDE1', 'CTBP1',
#        'CTBP2', 'CTCF', 'CTCFL', 'CUX1', 'DACH1', 'DDX20', 'DEAF1', 'DEK',
#        'DIDO1', 'DMAP1', 'DNMT1', 'DNMT3B', 'DPF2', 'DRAP1', 'E2F1',
#        'E2F4', 'E2F5', 'E2F6', 'E2F7', 'E2F8', 'E4F1', 'EBF1', 'EED',
# ...

# %%
experiment_url = ""
